# %%
# %run 'model.py'
# Out:
# Using TensorFlow backend.
# 6428 :: 6 :: 38568
# Epoch 1/5
# ...
# 38568/38568 [==============================] - 42s - loss: 0.0152 - val_loss: 0.0123
# Epoch 2/5
# 38568/38568 [==============================] - 38s - loss: 0.0101 - val_loss: 0.0121
# Epoch 3/5
# 38568/38568 [==============================] - 38s - loss: 0.0096 - val_loss: 0.0085
# Epoch 4/5
# 38568/38568 [==============================] - 38s - loss: 0.0093 - val_loss: 0.0089
# Epoch 5/5
# 38568/38568 [==============================] - 38s - loss: 0.0089 - val_loss: 0.0085
